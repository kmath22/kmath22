# %% [markdown]
# <a href="https://colab.research.google.com/github/kmath22/kmath22/blob/main/Final_Project_Benchmark_4_(Managing_Data).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# For this example, we will use variable H4TO3.  Below is it’s page from my personal codebook.
#
# We will use it to develop the code for data management, but first, we want to make sure the values of the variable match the codebook.
#
# ![image.png](data:image/png;base64,...)
#
#
# 1. Do you recall how to make a frequency table for H4TO3?  Start with that so you can make sure the unchanged variable has the same values as the codebook.
#
# Copy and paste the code to make that frequency table below.

# %%
#import Libraries researchpy
import pandas as pd

# %%
pip install researchpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
url='https://drive.google.com/file/d/1IbHzUMYKFBkmW3TIvryP7XJlW-WkmGEw/view?usp=sharing'
path= 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df = pd.read_csv(path)
df.head(5)
# Out:
#        AID  BIO_SEX        agew1 IMONTH4 IDAY4 IYEAR4   MACNO4 INTID4  \
# 0  5710027        2
# 1  5710131        2  19.42739726       5     6   2008  2288160    160
# 2  5710317        1
# 3  5710386        1  20.43013699       5    22   2008  2288238    238
# 4  5710455        2
#
#   BIO_SEX4 VERSION4  ... H4EO5C H4EO5D H4EO5E H4EO5F H4EO5G H4EO5H H4EO5I  \
# 0                    ...
# 1        2     V5.4  ...      0      0      0      0      0      0      0
# 2                    ...
# 3        1     V5.4  ...      0      0      0      0      0      0      0
# 4                    ...
#
#   H4EO5J H4EO6 H4EO7
# 0
# 1      0     2     1
# 2
# 3      0     4     1
# 4
#
# [5 rows x 976 columns]

# %% [markdown]
# 2. Now you’re ready to set H4TO3 with values of 6 and 8 to blank. Copy and paste the code that does that.  Then copy and paste the new frequency table.  (Just run the entire code file.)

# %%
df['Smoke_Reg'] = df['H4TO3']
df['Smoke_Reg'].value_counts()
# Out:
# 1    2312
# 7    1790
#      1390
# 0    1008
# 8       3
# 6       1
# Name: Smoke_Reg, dtype: int64

# %%
import researchpy as rp
rp.summary_cat(df['Smoke_Reg'])
# Out:
#     Variable Outcome  Count  Percent
# 0  Smoke_Reg       1   2312    35.55
# 1                  7   1790    27.52
# 2                      1390    21.37
# 3                  0   1008    15.50
# 4                  8      3     0.05
# 5                  6      1     0.02

# %%
df['Smoke_Reg'] = df['Smoke_Reg'].loc[ df['Smoke_Reg'] != ' ']
df['Smoke_Reg'] = df['Smoke_Reg'].loc[ df['Smoke_Reg'] != '6']
df['Smoke_Reg'] = df['Smoke_Reg'].loc[ df['Smoke_Reg'] != '8']
df['Smoke_Reg'].value_counts()
# Out:
# 1    2312
# 7    1790
# 0    1008
# Name: Smoke_Reg, dtype: int64

# %% [markdown]
# 3. Notice that your frequency table still has 7 -- the legitimate skips.  Recall that the people that got to skip this question said that they didn’t smoke.  So we want change this to 0.  Copy and paste the code that does that.  Then copy and paste the new frequency table.

# %%
df['Smoke_Reg'].replace( ['0','1','7'] , ['No', 'Yes', 'No'] , inplace = True) 
df['Smoke_Reg'].value_counts()
# Out:
# No     2798
# Yes    2312
# Name: Smoke_Reg, dtype: int64

# %%
rp.summary_cat(df['Smoke_Reg'])
# Out:
#     Variable Outcome  Count  Percent
# 0  Smoke_Reg      No   2798    54.76
# 1                Yes   2312    45.24

# %%
df['Smoke_Reg'].value_counts(normalize = True).plot(kind = 'pie' )
